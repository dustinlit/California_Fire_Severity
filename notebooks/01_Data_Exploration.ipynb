# %% [markdown]
# <link rel="stylesheet" href="notebooks/styles.css">

# %% [markdown]
# <div class="title-wrap">
#   <h1 class="title-main" style="font-weight: bold; font-size: 2.65rem; margin-bottom: 0.5rem;">
#   Spatial Data Science Approaches to Wildfire Severity Modeling
# </h1>
# <h2 class="title-sub" style="font-style: italic; font-size: 1.8rem; margin-top: 0rem; margin-bottom: 0.2rem;">
#   A GIS‑Driven, Tree‑Based Machine Learning Analysis of California Wildfires
# </h2>
# </div>

# %% [markdown]
# # Module 1: *Data Exploration*
# ##### Version Number: 4.0
# ---
# ### Contents
# > *Weather Data*\
# > *Wildfire Data*\
# > *Mesh Network*
# ---
# ### Notes
# - Integrate wildfire impact data with daily weather data from extracted from gridMET.
# ### Inputs
# - Daily Weather Readings - `gridmet_final.csv`
# - Wildfire Damage Data - `clean_fires.csv` (cleaned in module 1)
# - California Mesh Sampling Grid - `sampling_grids.csv` (built in appendix A)
# ---
# ### Outputs
# ---
# ### User Created Dependencies

# %%
import os
import sys

# Allow import of custom modules from the parent directory
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_utils import *
from src.model_utils import *
from src.plot_utils import *

# %% [markdown]
# ---
# ### Third Party Dependencies

# %%
# Data handling
import pandas as pd
import numpy as np
import geopandas as gpd
import datetime as dt
import jinja2

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import matplotlib.ticker as ticker

# %% [markdown]
# ---

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 1. Weather Data - `gridmet_final.csv`

# %% [markdown]
# > ### Source:
# > Weather variables (temperature, precipitation, humidity, etc.) were sourced from gridMET, a high-resolution (~4 km) gridded
# > dataset of daily meteorological data for the contiguous United States.\
# > URL: https://www.climatologylab.org/gridmet.html

# %%
weather = pd.read_csv('../data/raw/gridmet/gridmet_final.csv')
weather_meta = pd.read_csv('../data/raw/gridmet/weather_meta.csv')

# %%
weather_meta
# Out:
#                                                       Full Name  Units  \
# 0                                 Daily Maximum Air Temperature     °C
# 1                                 Daily Minimum Air Temperature     °C
# 2                                        Vapor Pressure Deficit    kPa
# 3                                     Maximum Relative Humidity      %
# 4                                     Minimum Relative Humidity      %
# 5                                             Specific Humidity  kg/kg
# 6                                                 Precipitation     mm
# 7                                                    Wind Speed    m/s
# 8                                               Solar Radiation   W/m²
# 9                                     Actual Evapotranspiration     mm
# 10                                                Burning Index  index
# 11                                     Energy Release Component  MJ/m²
# 12                                  100-hour Dead Fuel Moisture      %
# 13                                 1000-hour Dead Fuel Moisture      %
# 14                      Standardized Precipitation Index 30-Day  index
# 15                     Standardized Precipitation Index 180-Day  index
# 16   Standardized Precipitation Evapotranspiration Index 30-Day  index
# 17   Standardized Precipitation Evapotranspiration Index 90-Day  index
# 18  Standardized Precipitation Evapotranspiration Index 180-Day  index
# 19                                Palmer Drought Severity Index  index
#
#                                                                                                                         Description
# 0                                                                         Maximum air temperature at 2 meters above ground (Kelvin)
# 1                                                                         Minimum air temperature at 2 meters above ground (Kelvin)
# 2                  Difference between saturation vapor pressure and actual vapor pressure (kPa); indicates atmospheric drying power
# 3                                                                                   Maximum daily relative humidity (%) at 2 meters
# 4                                                                                   Minimum daily relative humidity (%) at 2 meters
# 5                                                                                  Mass of water vapor per unit mass of air (kg/kg)
# 6                                                                                                    Daily total precipitation (mm)
# 7                                                                                               Daily wind speed (m/s) at 10 meters
# 8                                                                                         Daily incoming shortwave radiation (W/m²)
# 9                                                                      Estimated evapotranspiration from actual vegetation (mm/day)
# 10      Fire danger index derived from temperature, humidity, wind, and fuel moisture; higher values indicate higher fire potential
# 11                                              Estimated energy release per unit area (MJ/m²); relates to potential fire intensity
# 12                                                             Moisture content of medium-size dead fuels (%) affecting fire spread
# 13                                                                   Moisture content of large dead fuels (%) affecting fire spread
# 14                                                  Short-term precipitation deficit; captures recent drying of fine fuels (grasses
# 15                         Longer-term precipitation deficit; indicates prolonged soil and vegetation drying affecting larger fuels
# 16         Short-term combined precipitation and evapotranspiration deficit; shows rapid drying of surface fuels influenced by heat
# 17      Seasonal combined precipitation and evapotranspiration deficit; reflects mid-term fuel stress including temperature effects
# 18  Long-term combined precipitation and evapotranspiration deficit; captures prolonged drought stress on vegetation and deep fuels
# 19                                               Long-term drought index combining temperature and precipitation to measure dryness

# %%
basic_explore(weather)
# Out:
# Rows:  446340  Columns:  22
# Duplicates  0
# Total NA values:  0  of  9819480 datapoints

# %% [markdown]
# ## 2. Wildfire Data - `fire_data.csv`
#
#
# Wildfire data was sourced from publically available records from the Cal Fire website. Estimation and cleaning are presented in Appendix B.
#
# Source: [CAL FIRE – Fire Incidents](https://www.fire.ca.gov/)
#
#
# - `Date` - Date fire started
# - `County` - County fire is located in
# - `Fire Name` - Official fire name for California
# - `FinalAcres` - Total acres burned per wildfire incident
# - `Estimated Damage` - Damages caused by wildfire incidents as estimated in Appendix B
# - `Fire_Latitude`,`Fire_Longitude` - Spatial data for wildfire start location

# %%
fire_data = pd.read_csv("../data/processed/fires_damage.csv")
basic_explore(fire_data)
# Out:
# Rows:  286  Columns:  7
# Duplicates  0
# Total NA values:  0  of  2002 datapoints

# %%
fire_data = fire_data.groupby(['Fire Name']).agg('first').reset_index()

# %%
fire_data
# Out:
#     Fire Name        Date  Estimated Damage  Fire_Latitude  Fire_Longitude  \
# 0        46th  2019-10-31      6.834400e+06      33.985706     -117.416998
# 1       Aborn  2019-07-15      7.600000e+05      37.320320     -121.754095
# 2        Aero  2024-06-17      1.201200e+06      37.985840     -120.653169
# 3        Agua  2022-07-18      1.001000e+06      37.483685     -120.021386
# 4     Airport  2024-09-09      9.990035e+07      33.635315     -117.413067
# ..        ...         ...               ...            ...             ...
# 252   Winding  2022-07-18      3.176000e+06      39.321337     -121.276706
# 253     Windy  2021-09-10      8.928000e+06      35.835964     -118.601402
# 254     Woods  2022-09-01      3.200000e+05      37.969815     -120.400392
# 255   Woolsey  2018-11-08      1.088312e+09      34.093722     -118.896672
# 256      Zogg  2020-09-27      6.924405e+07      40.527448     -122.618861
#
#           County  Damage per Day
# 0      Riverside    2.010118e+05
# 1    Santa Clara    2.235294e+04
# 2      Calaveras    3.532941e+04
# 3       Mariposa    2.944118e+04
# 4      Riverside    2.938246e+06
# ..           ...             ...
# 252         Yuba    9.341176e+04
# 253       Tulare    2.625882e+05
# 254     Tuolumne    9.411765e+03
# 255  Los Angeles    3.200918e+07
# 256       Shasta    2.036590e+06
#
# [257 rows x 7 columns]

# %%
after_total = fire_data['Estimated Damage'].values.sum()
total_fires = len(fire_data[fire_data['Estimated Damage'] > 0])
print(f"Total Estimated Value: ${after_total:,.0f} in {total_fires} wildfires.")
# Out:
# Total Estimated Value: $38,283,397,600 in 257 wildfires.

# %%
top_days = fire_data.sort_values('Estimated Damage', ascending=False).head(20)
plt.figure(figsize=(10, 10))
plt.barh(top_days['Date'].astype(str) + ' - ' + top_days['Fire Name'], top_days['Estimated Damage'])
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
plt.title("Top 20 Most Damaging Fires by Fire Name")
plt.xlabel("Estimated Damage")
plt.xticks(rotation=45)
plt.tight_layout()

# %%
fire_data_gdf = gpd.GeoDataFrame(
    fire_data,
    geometry=gpd.points_from_xy(fire_data['Fire_Longitude'], fire_data['Fire_Latitude']),
    crs='EPSG:4326'
)
plot_fire_damage(fire_data_gdf,'Estimated Damage')

# %% [markdown]
# ### 3. Load Sampling Grids - `Sampling_grids.csv`

# %% [markdown]
# <img src="../data/maps/grids.png" width="400">

# %%
## Load file
sample_meta = pd.read_csv("../data/raw/grid/Sampling_grids_meta.csv")
sample_meta
# Out:
#                        Field Name                        Alias Data Type  \
# 0                         grid_id                      Grid ID      Long
# 1                centroid_easting                      easting    Double
# 2               centroid_northing                     northing    Double
# 3                  influence_zone               Influence Zone    Double
# 4                  interface_zone                    Interface    Double
# 5                   intermix_zone                     Intermix    Double
# 6   dominant_province_description         Province Description      Text
# 7       dominant_province_percent    Dominant Province Percent    Double
# 8               sum_province_area            Sum Province Area    Double
# 9    dominant_section_description          Section Description      Text
# 10               sum_section_area             Sum Section Area    Double
# 11       dominant_section_percent     Dominant Section Percent    Double
# 12                      grid_area                    Grid Area    Double
# 13                   area_in_cali                 area_in_cali     Float
# 14                 forest_percent               Forest Percent      Long
# 15              developed_percent            Developed Percent      Long
# 16                  other_percent                Other Percent      Long
# 17            shrub_grass_percent          Shrub/Grass Percent      Long
# 18               wetlands_percent             Wetlands Percent      Long
# 19                elevation_range              Elevation Range    Double
# 20                 elevation_mean               Elevation Mean    Double
# 21                  elevation_std                Elevation STD    Double
# 22                      slope_max                    Slope Max    Double
# 23                    slope_range                  Slope Range    Double
# 24                     slope_mean                   Slope Mean    Double
# 25                      slope_std                    Slope STD    Double
# 26                 northness_mean               Northness Mean    Double
# 27                  eastness_mean                Eastness Mean    Double
# 28                  median_income           Mean Median Income    Double
# 29                      Sample_ID                    Sample_ID      Long
# 30             road_length_meters              Sum road_length    Double
# 31                   road_density                 Road Density    Double
# 32              power_line_meters  Power Line Length in Meters    Double
# 33             power_line_density       Density of Power Lines    Double
# 34                  total_housing                Total Housing    Double
# 35               total_population             Total Population    Double
# 36                housing_density              Housing Density    Double
# 37             population_density           Population Density    Double
# 38                      maximum_x         Maximum X Coordinate    Double
# 39                      minimum_y         Minimum Y Coordinate    Double
# 40                      maximum_y         Maximum Y Coordinate    Double
# 41                      minimum_x         Minimum X Coordinate    Double
#
#                                                                   Description  \
# 0                               Unique number representing each sampling grid
# 1                           EPSG 3310 easting position of each grids centroid
# 2                          EPSG 3310 northing position of each grids centroid
# 3                            Total amount of influence areas within each grid
# 4                            Total amount of interface areas within each grid
# 5                             Total amount of intermix areas within each grid
# 6                 Ecoregion province that makes up the most area in each grid
# 7   Percentage of ecoregion province that makes up the most area in each grid
# 8   Total area of ecoregion province that makes up the most area in each grid
# 9                  Ecoregion section that makes up the most area in each grid
# 10   Percentage of ecoregion section that makes up the most area in each grid
# 11   Total area of ecoregion section that makes up the most area in each grid
# 12                                                    Total area of each grid
# 13                       Total area of California that falls within each grid
# 14                                        Percent of forest land in each grid
# 15                                     Percent of developed land in each grid
# 16                          Percent of other (water,desert) land in each grid
# 17                              Percent of shrub/grasslands land in each grid
# 18                                      Percent of wetlands land in each grid
# 19          Difference between the minimum and maximum elevation in each grid
# 20                                             Average elevation in each grid
# 21                               Standard deviation of elevation in each grid
# 22                                                 Maximum slope in each grid
# 23              Difference between the minimum and maximum slope in each grid
# 24                                                 Average slope in each grid
# 25                               Standard deviation of elevation in each grid
# 26                  How strongly the slopes in the grid faces north (-1 to 1)
# 27                   How strongly the slopes in the grid faces east (-1 to 1)
# 28                                                 Median income in each grid
# 29                            Unique identifier to match with weather details
# 30                                        Total length of roads in each grid
# 31                                        Total density of roads in each grid
# 32                                  Total length of power lines in each grid
# 33                                  Total density of power lines in each grid
# 34                                    Count of all housing units in each grid
# 35                                              Population count in each grid
# 36                                            Density of housing in each grid
# 37                                         Density of population in each grid
# 38                                 Eastern bound (EPSG 4326 to match rasters)
# 39                                Southern bound (EPSG 4326 to match rasters)
# 40                                Northern bound (EPSG 4326 to match rasters)
# 41                                 Western bound (EPSG 4326 to match rasters)
#
#                   Units        Category
# 0                  none            Grid
# 1                meters        Location
# 2                meters        Location
# 3         square meters             WUI
# 4         square meters             WUI
# 5         square meters             WUI
# 6                  none          Region
# 7                  none          Region
# 8         square meters          Region
# 9                  none          Region
# 10                 none          Region
# 11        square meters          Region
# 12        square meters            Grid
# 13        square meters            Grid
# 14                 none            Fuel
# 15                 none            Fuel
# 16                 none            Fuel
# 17                 none            Fuel
# 18                 none            Fuel
# 19               meters       Elevation
# 20               meters       Elevation
# 21               meters       Elevation
# 22              degrees       Elevation
# 23              degrees       Elevation
# 24              degrees       Elevation
# 25              degrees       Elevation
# 26                 none       Elevation
# 27                 none       Elevation
# 28              dollars          Social
# 29                 none            Grid
# 30               meters  Infrastructure
# 31             1/meters  Infrastructure
# 32               meters  Infrastructure
# 33             1/meters  Infrastructure
# 34                house          Social
# 35               people          Social
# 36   house/square meter          Social
# 37  people/square meter          Social
# 38              degrees            Grid
# 39              degrees            Grid
# 40              degrees            Grid
# 41              degrees            Grid
